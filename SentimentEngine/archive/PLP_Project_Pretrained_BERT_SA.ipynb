# %% [markdown]
# This method used just HF pretrained BERT and tokenizer for sentiment data only and output a score of 0 to 4

# %%
# !pip install transformers

# %%
from transformers import AutoTokenizer,AutoModelForSequenceClassification
import numpy as np
import pandas as pd

# %%
tokenizer = AutoTokenizer.from_pretrained('nlptown/bert-base-multilingual-uncased-sentiment')
model = AutoModelForSequenceClassification.from_pretrained('nlptown/bert-base-multilingual-uncased-sentiment')
# Out:
# Downloading:   0%|          | 0.00/39.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/953 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/851k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/112 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/638M [00:00<?, ?B/s]

# %%
def checkSenti(sentence):
  sentiment = model(tokenizer.encode(sentence, return_tensors='pt'))
  result = int(torch.argmax(sentiment.logits))+1
  return result

# %%
checkSenti('I hate the new movie very much!')
# Out:
# 1

# %%
checkSenti('I do not really like this movie.')
# Out:
# 2

# %%
checkSenti('I think this movie is just ok.')
# Out:
# 3

# %%
checkSenti('I think this movie is pretty good.')
# Out:
# 4

# %%
checkSenti('I like this movie.')
# Out:
# 5
